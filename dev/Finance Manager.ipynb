# %%
import pandas as pd
import numpy as np
import json
import mongo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\iccr_sih22\Sangmanch-DSML\dev\Finance Manager.ipynb Cell 1 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/iccr_sih22/Sangmanch-DSML/dev/Finance%20Manager.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
#       <a href='vscode-notebook-cell:/d%3A/iccr_sih22/Sangmanch-DSML/dev/Finance%20Manager.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> import json
# ----> <a href='vscode-notebook-cell:/d%3A/iccr_sih22/Sangmanch-DSML/dev/Finance%20Manager.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a> import mongo
#
# ModuleNotFoundError: No module named 'mongo'

# %%
user['expense'] = user['expense'].str[1:].astype('float32')
user['budget'] = user['budget'].str[1:].astype('float32')
user
# Out:
#      role                      user_id                  event_id  \
# 0    user      hcuddyg@telegraph.co.uk  62d3b99ffc13ae55b700014a
# 1    user   gwehnerr6@sciencedaily.com  62d3b99ffc13ae55b700014b
# 2    user      hcuddyg@telegraph.co.uk  62d3b99ffc13ae55b700014c
# 3    user  odumbleton12@infoseek.co.jp  62d3b99ffc13ae55b700014d
# 4    user             oskehane@ovh.net  62d3b99ffc13ae55b700014e
# ..    ...                          ...                       ...
# 495  user       eblaney14@berkeley.edu  62d3b9a1fc13ae55b7000339
# 496  user             cjanssonp@va.gov  62d3b9a1fc13ae55b700033a
# 497  user            mmcviey@bbc.co.uk  62d3b9a1fc13ae55b700033b
# 498  user       eblaney14@berkeley.edu  62d3b9a1fc13ae55b700033c
# 499  user          ybrettel5@youku.com  62d3b9a1fc13ae55b700033d
#
#               event_name  reach      expense       budget  \
# 0           Republic Day  28202  7570.330078  5589.049805
# 1               Baisakhi  66508  8757.169922  8277.919922
# 2       Independence Day   1194  3010.739990  5740.959961
# 3    Krishna Janmashtami  85467  3467.350098  8108.549805
# 4       Independence Day  39552  9628.019531  4283.500000
# ..                   ...    ...          ...          ...
# 495               Diwali  64130  1484.969971  7480.500000
# 496         Republic Day  24723  3040.320068  5267.240234
# 497       Mewar Festival  50948  7249.919922  7462.000000
# 498       Raksha Bandhan   1054  4957.870117  4805.089844
# 499      Makar Sankranti  64790  5316.549805  4007.810059
#
#                     city             country  status  forward_ga
# 0                Seattle       United States    True        True
# 1                 Jember           Indonesia    True       False
# 2                Sevilla            Colombia    True       False
# 3               Veracruz              Panama    True       False
# 4    Las Matas de Farfán  Dominican Republic    True        True
# ..                   ...                 ...     ...         ...
# 495              Refojos            Portugal    True        True
# 496             Varadero                Cuba    True       False
# 497       Pedro Leopoldo              Brazil    True        True
# 498                Kālia          Bangladesh    True       False
# 499               Bentiu         South Sudan   False        True
#
# [500 rows x 11 columns]

# %%
user_byEmail_reach = pd.pivot_table(user, values='reach', index=['user_id'], aggfunc=np.sum)
user_byEmail_expense = pd.pivot_table(user, values='expense', index=['user_id'], aggfunc=np.sum)

# %%
buffer = user.groupby('user_id').sum()['expense']
buffer.to_list()
# Out:
# [187053.234375,
#  204459.765625,
#  228192.65625,
#  168322.4375,
#  222790.21875,
#  183479.84375,
#  248531.109375,
#  211894.03125,
#  197908.125,
#  153408.453125,
#  252752.015625,
#  201026.234375,
#  157267.8125,
#  152089.21875]

# %%
user['expense']
# Out:
# 0      7570.330078
# 1      8757.169922
# 2      3010.739990
# 3      3467.350098
# 4      9628.019531
#           ...
# 495    1484.969971
# 496    3040.320068
# 497    7249.919922
# 498    4957.870117
# 499    5316.549805
# Name: expense, Length: 500, dtype: float32
